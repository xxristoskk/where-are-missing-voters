# %% [markdown]
# # Where Are The (Not) Voters?
# Tynan Challenor from Stanford University published their finding in a paper called "Predicting Votes From Census Data". They gathered data from a survey given by Census that took place after the 2016 election, and used Logistic Regression, Support Vector Machine, and Naive Bayes models to predict whether or not a person is likely to vote. This inspired me to see if I could do the same, but rather than predicting an individual's likeliness to vote, I want to predict whether or not a county will have a low voter turnout.

# %%
## Import necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import f1_score, precision_score, classification_report, recall_score, accuracy_score, roc_curve, auc, roc_auc_score,confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %% [markdown]
# I gathered my data from two different sources--one from the 2016 presidential election, which includes most of my features, and one from the 2018 midterm election.

# %%
## Election 2018 dataset
elect18 = pd.read_csv('/home/xristsos/Documents/2016 election/national-files/us-senate-wide.csv')
elect18 = pd.DataFrame(elect18[['state','county','total.votes']])

# %%
## Cleaning 2018 data
elect18.columns = ['state','county','total_votes_senate18']
elect18.county = elect18.county + ' County'
elect18.sort_values('county',inplace=True)
elect18.set_index('county',inplace=True)
elect18.head()
# Out:
#                 state  total_votes_senate18
# county
# Abbot County       ME                   307
# Abington County    MA                  7337
# Accomack County    VA                 12745
# Acton County       MA                 11024
# Acton County       ME                  1209

# %%
##Election 2016 dataset
elect16 = pd.read_json('/home/xristsos/Downloads/usa-2016-presidential-election-by-county.json')
## Converting all the dictionaries in Fields columns to one data frame
elect16 = pd.DataFrame(data=[x for x in elect16['fields']])

##Create copy for GeoPandas
geo_df = elect16

# %%
## Cleaning 2016 data
elect16.drop(['state','geo_shape','temp_bins'],axis=1,inplace=True)
elect16.rename(columns={'st':'state'},inplace=True)
elect16.county = [x.split(', ') for x in elect16.county]
elect16.county = [x[0] for x in elect16.county]
elect16.set_index('county',inplace=True)

##Fill and remove missing data
elect16.teen_births.fillna(elect16.teen_births.median(),inplace=True)
def remove_cols(df):
    for col in df.columns:
        if '16' in col:
            df.drop(col,axis=1,inplace=True)
        elif df[col].isna().sum() > 40:
            df.drop(col,axis=1,inplace=True)
remove_cols(elect16)

# %%
## Describe population data
elect16.total_population.describe()
# Out:
# count    3.143000e+03
# mean     9.707373e+04
# std      3.110648e+05
# min      8.100000e+01
# 25%      1.102850e+04
# 50%      2.563100e+04
# 75%      6.589200e+04
# max      9.801950e+06
# Name: total_population, dtype: float64

# %%
## Adding new columns
##create a columnn for the percentage of voter turnout
elect16['voter_percent'] = elect16['votes'] / elect16['total_population']
## ranks the size of county from 1 to 5
scores = []
for i in elect16.total_population:
    if i <= 5000:
        scores.append(1)
    elif i > 5000 and i <= 15000:
        scores.append(2)
    elif i > 15000 and i <= 30000:
        scores.append(3)
    elif i > 30000 and i <= 50000:
        scores.append(4)
    elif i > 50000:
        scores.append(5)
elect16['size_rank'] = scores
elect16.voter_percent.fillna(elect16.voter_percent.mean(),inplace=True)

# %%
## Merge the two dataframes by state and county
df = pd.merge(elect18,elect16,how='inner',on=['county','state'])
df.drop_duplicates(inplace=True)
df.head(10)
# Out:
#                 state  total_votes_senate18          acfs  adult_obesity  \
# county
# Accomack County    VA                 12745  1.577735e-05          0.355
# Adair County       MO                  8695  1.127980e-04          0.305
# Adams County       MS                 10760  1.345093e-04          0.361
# Adams County       MS                 10826  1.345093e-04          0.361
# Adams County       WA                  4232  1.508938e-04          0.373
# Adams County       WI                  9399  4.084924e-05          0.302
# Adams County       IN                 11146  4.519606e-05          0.304
# Adams County       PA                 39102  2.454162e-06          0.283
# Adams County       OH                  8643  9.187509e-07          0.307
# Adams County       ND                  1164  2.409457e-05          0.331
#
#                  adults_65_and_older_living_in_poverty  \
# county
# Accomack County                                  16.50
# Adair County                                     13.40
# Adams County                                     20.05
# Adams County                                     20.05
# Adams County                                     13.85
# Adams County                                      6.40
# Adams County                                      8.05
# Adams County                                      7.05
# Adams County                                     16.30
# Adams County                                     15.10
#
#                  african_american_population  amerindian  asian  \
# county
# Accomack County                        28.35        0.20   0.40
# Adair County                            1.50        0.30   1.50
# Adams County                           54.55        0.25   0.25
# Adams County                           54.55        0.25   0.25
# Adams County                            0.25        0.35   0.30
# Adams County                            3.00        0.85   0.55
# Adams County                            0.30        0.15   0.20
# Adams County                            1.50        0.10   0.70
# Adams County                            0.35        0.35   0.10
# Adams County                            0.15        0.80   0.20
#
#                  asian_american_population  at_least_bachelor_s_degree  ...  \
# county                                                                  ...
# Accomack County                       0.40                        18.0  ...
# Adair County                          1.50                        25.5  ...
# Adams County                          0.25                        19.3  ...
# Adams County                          0.25                        19.3  ...
# Adams County                          0.30                        13.4  ...
# Adams County                          0.55                        10.8  ...
# Adams County                          0.20                        12.2  ...
# Adams County                          0.70                        18.5  ...
# Adams County                          0.10                        10.7  ...
# Adams County                          0.20                        18.4  ...
#
#                  total12  total_population  unemployment  uninsured    votes  \
# county
# Accomack County  16051.0             35843         0.069      0.204  15755.0
# Adair County     10126.0             25204         0.060      0.184  10137.0
# Adams County     15447.0             31886         0.094      0.217  12214.0
# Adams County     15447.0             31886         0.094      0.217  12214.0
# Adams County      4793.0             17878         0.088      0.248   4081.0
# Adams County     10287.0             20637         0.099      0.122  10107.0
# Adams County     13011.0             34171         0.078      0.189  13039.0
# Adams County     42457.0            101209         0.066      0.125  47138.0
# Adams County     11118.0             28346         0.108      0.164  11063.0
# Adams County      1286.0              2317         0.027      0.136   1206.0
#
#                  white  white_asian  white_not_latino_population  \
# county
# Accomack County  61.05        61.45                        61.05
# Adair County     93.00        94.50                        93.00
# Adams County     40.40        40.65                        40.40
# Adams County     40.40        40.65                        40.40
# Adams County     40.85        41.15                        40.85
# Adams County     91.25        91.80                        91.25
# Adams County     94.85        95.05                        94.85
# Adams County     90.70        91.40                        90.70
# Adams County     96.90        97.00                        96.90
# Adams County     96.45        96.65                        96.45
#
#                  voter_percent  size_rank
# county
# Accomack County       0.439556          4
# Adair County          0.402198          3
# Adams County          0.383052          4
# Adams County          0.383052          4
# Adams County          0.228269          3
# Adams County          0.489751          3
# Adams County          0.381581          4
# Adams County          0.465749          5
# Adams County          0.390284          3
# Adams County          0.520501          1
#
# [10 rows x 79 columns]

# %%
## Take the percent of voters from the midterm election and take the average turnout from the two elections
df['2018_vote_percent'] = df.total_votes_senate18 / df.total_population
df1 = pd.DataFrame(df.drop(['voter_percent','2018_vote_percent'],axis=1))
df1['avg_percent'] = (df['voter_percent'] + df['2018_vote_percent']) / 2

# %% [markdown]
# Now that I have all the data in one dataframe, but before I start exploring, I have to define my target variable "low voter turnout". It was difficult for me to decide, because average national voter turnout has been consistently around 45%, which is already low. For this model to be applicable for campaign purposes, I chose to define everything below 38% as a low turnout.

# %%
df1.avg_percent.describe()
# Out:
# count    1973.000000
# mean        0.413598
# std         0.088057
# min         0.184366
# 25%         0.356250
# 50%         0.407813
# 75%         0.468746
# max         0.980144
# Name: avg_percent, dtype: float64

# %%
df1['low_turnout'] = [1 if x <= .38 else 0 for x in df1['avg_percent']]
## Remove outliers
df1 = pd.DataFrame(df1[df1['avg_percent']<.9])
target = pd.DataFrame(df1['low_turnout'])

# %%
features = pd.DataFrame(df1[['gini_coefficient','size_rank','asian_american_population','african_american_population',
                      'uninsured','production_transportation_and_material_moving_occupations',
                      'poverty_rate_below_federal_poverty_threshold','construction_extraction_maintenance_and_repair_occupations',
                      'less_than_high_school','at_least_bachelor_s_degree','unemployment',
                      'latino_population','management_professional_and_related_occupations','native_american_population',
                      'sales_and_office_occupations','white_not_latino_population']])

# %% [markdown]
# As a consequence of the turnout definition, my target variable is unbalanced. I will deal with this during model selection.

# %% [markdown]
# # Exploratory Data Analysis

# %%
## Checking for correlated features
features.corr()
# Out:
#                                                     gini_coefficient  \
# gini_coefficient                                            1.000000
# size_rank                                                   0.070471
# asian_american_population                                   0.089158
# african_american_population                                 0.381457
# uninsured                                                   0.353263
# production_transportation_and_material_moving_o...         -0.179492
# poverty_rate_below_federal_poverty_threshold                0.556957
# construction_extraction_maintenance_and_repair_...         -0.082660
# less_than_high_school                                       0.348280
# at_least_bachelor_s_degree                                  0.120154
# unemployment                                                0.215396
# latino_population                                           0.207180
# management_professional_and_related_occupations             0.028199
# native_american_population                                  0.052239
# sales_and_office_occupations                                0.082006
# white_not_latino_population                                -0.436856
#
#                                                     size_rank  \
# gini_coefficient                                     0.070471
# size_rank                                            1.000000
# asian_american_population                            0.337948
# african_american_population                          0.051340
# uninsured                                           -0.290476
# production_transportation_and_material_moving_o...  -0.094792
# poverty_rate_below_federal_poverty_threshold        -0.168043
# construction_extraction_maintenance_and_repair_...  -0.293166
# less_than_high_school                               -0.205300
# at_least_bachelor_s_degree                           0.428321
# unemployment                                         0.191825
# latino_population                                    0.017355
# management_professional_and_related_occupations      0.159406
# native_american_population                          -0.091815
# sales_and_office_occupations                         0.590630
# white_not_latino_population                         -0.081014
#
#                                                     asian_american_population  \
# gini_coefficient                                                     0.089158
# size_rank                                                            0.337948
# asian_american_population                                            1.000000
# african_american_population                                          0.006158
# uninsured                                                           -0.157307
# production_transportation_and_material_moving_o...                  -0.281700
# poverty_rate_below_federal_poverty_threshold                        -0.172542
# construction_extraction_maintenance_and_repair_...                  -0.273966
# less_than_high_school                                               -0.168422
# at_least_bachelor_s_degree                                           0.500096
# unemployment                                                         0.015776
# latino_population                                                    0.129817
# management_professional_and_related_occupations                      0.375532
# native_american_population                                          -0.047370
# sales_and_office_occupations                                         0.205603
# white_not_latino_population                                         -0.262770
#
#                                                     african_american_population  \
# gini_coefficient                                                       0.381457
# size_rank                                                              0.051340
# asian_american_population                                              0.006158
# african_american_population                                            1.000000
# uninsured                                                              0.187877
# production_transportation_and_material_moving_o...                     0.086845
# poverty_rate_below_federal_poverty_threshold                           0.478083
# construction_extraction_maintenance_and_repair_...                    -0.064769
# less_than_high_school                                                  0.369127
# at_least_bachelor_s_degree                                            -0.059646
# unemployment                                                           0.366350
# latino_population                                                     -0.098978
# management_professional_and_related_occupations                       -0.132382
# native_american_population                                            -0.085353
# sales_and_office_occupations                                           0.068574
# white_not_latino_population                                           -0.568028
#
#                                                     uninsured  \
# gini_coefficient                                     0.353263
# size_rank                                           -0.290476
# asian_american_population                           -0.157307
# african_american_population                          0.187877
# uninsured                                            1.000000
# production_transportation_and_material_moving_o...  -0.051535
# poverty_rate_below_federal_poverty_threshold         0.539317
# construction_extraction_maintenance_and_repair_...   0.352528
# less_than_high_school                                0.617461
# at_least_bachelor_s_degree                          -0.346462
# unemployment                                         0.163972
# latino_population                                    0.526012
# management_professional_and_related_occupations     -0.301912
# native_american_population                           0.091238
# sales_and_office_occupations                        -0.204306
# white_not_latino_population                         -0.516142
#
#                                                     production_transportation_and_material_moving_occupations  \
# gini_coefficient                                                                            -0.179492
# size_rank                                                                                   -0.094792
# asian_american_population                                                                   -0.281700
# african_american_population                                                                  0.086845
# uninsured                                                                                   -0.051535
# production_transportation_and_material_moving_o...                                           1.000000
# poverty_rate_below_federal_poverty_threshold                                                 0.160969
# construction_extraction_maintenance_and_repair_...                                           0.037513
# less_than_high_school                                                                        0.308996
# at_least_bachelor_s_degree                                                                  -0.578239
# unemployment                                                                                 0.205454
# latino_population                                                                           -0.228216
# management_professional_and_related_occupations                                             -0.637968
# native_american_population                                                                  -0.118834
# sales_and_office_occupations                                                                -0.229068
# white_not_latino_population                                                                  0.198587
#
#                                                     poverty_rate_below_federal_poverty_threshold  \
# gini_coefficient                                                                        0.556957
# size_rank                                                                              -0.168043
# asian_american_population                                                              -0.172542
# african_american_population                                                             0.478083
# uninsured                                                                               0.539317
# production_transportation_and_material_moving_o...                                      0.160969
# poverty_rate_below_federal_poverty_threshold                                            1.000000
# construction_extraction_maintenance_and_repair_...                                      0.103282
# less_than_high_school                                                                   0.692843
# at_least_bachelor_s_degree                                                             -0.407777
# unemployment                                                                            0.446138
# latino_population                                                                       0.232308
# management_professional_and_related_occupations                                        -0.423491
# native_american_population                                                              0.194726
# sales_and_office_occupations                                                           -0.149827
# white_not_latino_population                                                            -0.519825
#
#                                                     construction_extraction_maintenance_and_repair_occupations  \
# gini_coefficient                                                                            -0.082660
# size_rank                                                                                   -0.293166
# asian_american_population                                                                   -0.273966
# african_american_population                                                                 -0.064769
# uninsured                                                                                    0.352528
# production_transportation_and_material_moving_o...                                           0.037513
# poverty_rate_below_federal_poverty_threshold                                                 0.103282
# construction_extraction_maintenance_and_repair_...                                           1.000000
# less_than_high_school                                                                        0.311388
# at_least_bachelor_s_degree                                                                  -0.447066
# unemployment                                                                                 0.031624
# latino_population                                                                            0.115434
# management_professional_and_related_occupations                                             -0.452590
# native_american_population                                                                   0.021452
# sales_and_office_occupations                                                                -0.234052
# white_not_latino_population                                                                 -0.006793
#
#                                                     less_than_high_school  \
# gini_coefficient                                                 0.348280
# size_rank                                                       -0.205300
# asian_american_population                                       -0.168422
# african_american_population                                      0.369127
# uninsured                                                        0.617461
# production_transportation_and_material_moving_o...               0.308996
# poverty_rate_below_federal_poverty_threshold                     0.692843
# construction_extraction_maintenance_and_repair_...               0.311388
# less_than_high_school                                            1.000000
# at_least_bachelor_s_degree                                      -0.585945
# unemployment                                                     0.374371
# latino_population                                                0.434190
# management_professional_and_related_occupations                 -0.567013
# native_american_population                                      -0.008438
# sales_and_office_occupations                                    -0.205701
# white_not_latino_population                                     -0.534247
#
#                                                     at_least_bachelor_s_degree  \
# gini_coefficient                                                      0.120154
# size_rank                                                             0.428321
# asian_american_population                                             0.500096
# african_american_population                                          -0.059646
# uninsured                                                            -0.346462
# production_transportation_and_material_moving_o...                   -0.578239
# poverty_rate_below_federal_poverty_threshold                         -0.407777
# construction_extraction_maintenance_and_repair_...                   -0.447066
# less_than_high_school                                                -0.585945
# at_least_bachelor_s_degree                                            1.000000
# unemployment                                                         -0.265758
# latino_population                                                    -0.022668
# management_professional_and_related_occupations                       0.790432
# native_american_population                                           -0.054828
# sales_and_office_occupations                                          0.327751
# white_not_latino_population                                          -0.008115
#
#                                                     unemployment  \
# gini_coefficient                                        0.215396
# size_rank                                               0.191825
# asian_american_population                               0.015776
# african_american_population                             0.366350
# uninsured                                               0.163972
# production_transportation_and_material_moving_o...      0.205454
# poverty_rate_below_federal_poverty_threshold            0.446138
# construction_extraction_maintenance_and_repair_...      0.031624
# less_than_high_school                                   0.374371
# at_least_bachelor_s_degree                             -0.265758
# unemployment                                            1.000000
# latino_population                                       0.028775
# management_professional_and_related_occupations        -0.381139
# native_american_population                              0.079015
# sales_and_office_occupations                            0.110746
# white_not_latino_population                            -0.297014
#
#                                                     latino_population  \
# gini_coefficient                                             0.207180
# size_rank                                                    0.017355
# asian_american_population                                    0.129817
# african_american_population                                 -0.098978
# uninsured                                                    0.526012
# production_transportation_and_material_moving_o...          -0.228216
# poverty_rate_below_federal_poverty_threshold                 0.232308
# construction_extraction_maintenance_and_repair_...           0.115434
# less_than_high_school                                        0.434190
# at_least_bachelor_s_degree                                  -0.022668
# unemployment                                                 0.028775
# latino_population                                            1.000000
# management_professional_and_related_occupations             -0.065958
# native_american_population                                  -0.019975
# sales_and_office_occupations                                 0.002506
# white_not_latino_population                                 -0.688333
#
#                                                     management_professional_and_related_occupations  \
# gini_coefficient                                                                           0.028199
# size_rank                                                                                  0.159406
# asian_american_population                                                                  0.375532
# african_american_population                                                               -0.132382
# uninsured                                                                                 -0.301912
# production_transportation_and_material_moving_o...                                        -0.637968
# poverty_rate_below_federal_poverty_threshold                                              -0.423491
# construction_extraction_maintenance_and_repair_...                                        -0.452590
# less_than_high_school                                                                     -0.567013
# at_least_bachelor_s_degree                                                                 0.790432
# unemployment                                                                              -0.381139
# latino_population                                                                         -0.065958
# management_professional_and_related_occupations                                            1.000000
# native_american_population                                                                 0.026192
# sales_and_office_occupations                                                               0.031207
# white_not_latino_population                                                                0.072482
#
#                                                     native_american_population  \
# gini_coefficient                                                      0.052239
# size_rank                                                            -0.091815
# asian_american_population                                            -0.047370
# african_american_population                                          -0.085353
# uninsured                                                             0.091238
# production_transportation_and_material_moving_o...                   -0.118834
# poverty_rate_below_federal_poverty_threshold                          0.194726
# construction_extraction_maintenance_and_repair_...                    0.021452
# less_than_high_school                                                -0.008438
# at_least_bachelor_s_degree                                           -0.054828
# unemployment                                                          0.079015
# latino_population                                                    -0.019975
# management_professional_and_related_occupations                       0.026192
# native_american_population                                            1.000000
# sales_and_office_occupations                                         -0.077729
# white_not_latino_population                                          -0.217830
#
#                                                     sales_and_office_occupations  \
# gini_coefficient                                                        0.082006
# size_rank                                                               0.590630
# asian_american_population                                               0.205603
# african_american_population                                             0.068574
# uninsured                                                              -0.204306
# production_transportation_and_material_moving_o...                     -0.229068
# poverty_rate_below_federal_poverty_threshold                           -0.149827
# construction_extraction_maintenance_and_repair_...                     -0.234052
# less_than_high_school                                                  -0.205701
# at_least_bachelor_s_degree                                              0.327751
# unemployment                                                            0.110746
# latino_population                                                       0.002506
# management_professional_and_related_occupations                         0.031207
# native_american_population                                             -0.077729
# sales_and_office_occupations                                            1.000000
# white_not_latino_population                                            -0.065581
#
#                                                     white_not_latino_population
# gini_coefficient                                                      -0.436856
# size_rank                                                             -0.081014
# asian_american_population                                             -0.262770
# african_american_population                                           -0.568028
# uninsured                                                             -0.516142
# production_transportation_and_material_moving_o...                     0.198587
# poverty_rate_below_federal_poverty_threshold                          -0.519825
# construction_extraction_maintenance_and_repair_...                    -0.006793
# less_than_high_school                                                 -0.534247
# at_least_bachelor_s_degree                                            -0.008115
# unemployment                                                          -0.297014
# latino_population                                                     -0.688333
# management_professional_and_related_occupations                        0.072482
# native_american_population                                            -0.217830
# sales_and_office_occupations                                          -0.065581
# white_not_latino_population                                            1.000000

# %%
###Calculate PCA and plot results
## Needs more work
from sklearn.decomposition import PCA
pca = PCA(n_components=8)
components = pca.fit_transform(features)

# %%
components
# Out:
# array([[ 21.95214635,  17.32079013,   1.96819573, ...,   1.47277762,
#           1.29500598,   1.03576953],
#        [-15.14327132,  -0.91183641,   5.83124387, ...,  -7.17988726,
#          -3.6466129 ,  -6.42727797],
#        [ 46.26073341,  41.21614857,  11.23169258, ...,   2.25807361,
#          -6.00526143,  -5.51261316],
#        ...,
#        [ 57.72701318, -31.09009232, -11.45963288, ...,   1.81428716,
#          -2.17583136,  -0.99367105],
#        [100.68217623, -47.98293226, -24.51684333, ...,  -4.05491266,
#           2.54730051,  -3.11151708],
#        [102.08483381, -47.59100571, -27.89396689, ...,  -5.96102475,
#          -5.04152651,  -6.7108052 ]])

# %%
fig = plt.figure(figsize=(12,9))
ax = fig.add_subplot(1,1,1)
ax.scatter(components[:,0],components[:,1])

# %%
fig = plt.figure(figsize=(10,8))
sns.barplot(x=pca.explained_variance_,y=features.columns[:8])

# %%
fig = plt.figure(figsize=(12,9))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('explained variance ratio')
# Out:
# Text(0, 0.5, 'explained variance ratio')

# %% [markdown]
# # Model Selection

# %%
X = features
xTrain,xTest,yTrain,yTest = train_test_split(X,target,test_size=.25)

# %%
## Helper function that calculates scores for models
def calc_scores(yTest,yPred):
    print('Precision: ', precision_score(yTest,yPred))
    print('F1: ', f1_score(yTest,yPred))
    print('Accuracy: ', accuracy_score(yTest,yPred))
    print('Recall: ', recall_score(yTest,yPred))
    falseP,trueP,thresholds = roc_curve(yTest,yPred)
    roc_auc = auc(falseP,trueP)
    print('ROC_AUC: ', roc_auc)
    print(confusion_matrix(yTest,yPred))

# %%
def grid_search(xTrain,xTest,yTrain,yTest):
    gs = GridSearchCV(estimator=RandomForestClassifier(),
                     param_grid={'max_depth': [3,8],
                                 'n_estimators': (25,50,75,100,500,1000),
                                 'max_features': (4,6,8)},
                     cv=4,n_jobs=-1,scoring='balanced_accuracy')
    model = gs.fit(xTrain,yTrain)
    print(f'Best score: {model.best_score_}')
    print(f'Best parms: {model.best_params_}')

# %%
grid_search(xTrain,xTest,yTrain,yTest)
# Out:
# /home/xristsos/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:740: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# Best score: 0.799557890700484
# Best parms: {'max_depth': 8, 'max_features': 6, 'n_estimators': 1000}

# %% [markdown]
# # Random Forest

# %%
#Random Forest
print('Random Forest: ')
rf = RandomForestClassifier(n_estimators=1000,max_depth=8,max_features=6)
rf.fit(xTrain,yTrain)
rf_y = rf1.predict(xTest)
calc_scores(yTest,rf_y)

# %% [markdown]
# # Logistic Regression

# %%
lr1 = LogisticRegression()
lr1.fit(xTrain,yTrain)
lr1_y = lr1.predict(xTest)
calc_scores(yTest,lr1_y)

# %% [markdown]
# # XGBoost

# %%
def boost_search(xTrain,xTest,yTrain,yTest):
    gs = GridSearchCV(estimator=XGBClassifier(),
                     param_grid={'max_depth': [3,8],
                                 'n_estimators': (25,50,75,100,500,1000),
                                 'max_features': (4,6,8),
                                 'eta': (.1,.07,.05,.03,.01),
                                 'min_child_weight': (1,2),
                                 'sub_sample': (.3,.5,.7),
                                 'min_samples_split': (.4,.5,.6,.7)},
                     cv=4,n_jobs=-1,scoring='balanced_accuracy')
    model = gs.fit(xTrain,yTrain)
    print(f'Best score: {model.best_score_}')
    print(f'Best parms: {model.best_params_}')

# %%
boost_search(xTrain,xTest,yTrain,yTest)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-844c60237640> in <module>
# ----> 1 boost_search(xTrain,xTest,yTrain,yTest)
#
# <ipython-input-32-8d0bd9f0117b> in boost_search(xTrain, xTest, yTrain, yTest)
#       9                                  'min_samples_split': (.4,.5,.6,.7)},
#      10                      cv=4,n_jobs=-1,scoring='balanced_accuracy')
# ---> 11     model = gs.fit(xTrain,yTrain)
#      12     print(f'Best score: {model.best_score_}')
#      13     print(f'Best parms: {model.best_params_}')
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     720                 return results_container[0]
#     721
# --> 722             self._run_search(evaluate_candidates)
#     723
#     724         results = results_container[0]
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1189     def _run_search(self, evaluate_candidates):
#    1190         """Search all candidates in param_grid"""
# -> 1191         evaluate_candidates(ParameterGrid(self.param_grid))
#    1192
#    1193
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     709                                for parameters, (train, test)
#     710                                in product(candidate_params,
# --> 711                                           cv.split(X, y, groups)))
#     712
#     713                 all_candidate_params.extend(candidate_params)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     928
#     929             with self._backend.retrieval_context():
# --> 930                 self.retrieve()
#     931             # Make sure that we get a last message telling us we are done
#     932             elapsed_time = time.time() - self._start_time
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# ~/anaconda3/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
xg1 = XGBClassifier(silent=0,eta=.1,min_child_weight=2,sub_sample=.7,eval_metric='auc',n_estimators=1000,
                    max_depth=5,min_samples_split=.7,max_features=9)
xg1.fit(xTrain,yTrain)
xg1_y = xg1.predict(xTest)
calc_scores(yTest,xg1_y)

# %% [markdown]
# # The Final Model!

# %% [markdown]
# # Folium / GeoPandas stuff idk how to use yet

# %%
geo_df['geo_shape'].head()

# %%
import folium
import geopandas

# %%
gdf = geopandas.GeoDataFrame(geo_df,geometry=geopandas.points_from_xy())

# %%
geo = geopandas.read_file('/home/xristsos/flatiron/projects/where-are-missing-voters/geo_test.json')
# geo_df = geopandas.GeoDataFrame('/home/xristsos/flatiron/projects/where-are-missing-voters/geo_test.json')

# %%
folium.features.Choropleth('/home/xristsos/flatiron/projects/where-are-missing-voters/geo_test.json')

# %%
m = folium.Map(location=[46.59, -92.68], zoom_start=7)

# %%
m
